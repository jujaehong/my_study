# %%
import numbers as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/jaehong/Documents/GitHub/my_study/python_study/avocado.csv',index_col=0)

# %%
df
# Out:
#           Date  AveragePrice  Total Volume     4046       4225    4770
# 0   2015-12-27          1.33      64236.62  1036.74   54454.85   48.16  \
# 1   2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2   2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3   2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4   2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ..         ...           ...           ...      ...        ...     ...
# 7   2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 8   2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 9   2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 10  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 11  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year
# 0      8696.87     8603.62       93.25          0.0  conventional  2015  \
# 1      9505.56     9408.07       97.49          0.0  conventional  2015
# 2      8145.35     8042.21      103.14          0.0  conventional  2015
# 3      5811.16     5677.40      133.76          0.0  conventional  2015
# 4      6183.95     5986.26      197.69          0.0  conventional  2015
# ..         ...         ...         ...          ...           ...   ...
# 7     13498.67    13066.82      431.85          0.0       organic  2018
# 8      9264.84     8940.04      324.80          0.0       organic  2018
# 9      9394.11     9351.80       42.31          0.0       organic  2018
# 10    10969.54    10919.54       50.00          0.0       organic  2018
# 11    12014.15    11988.14       26.01          0.0       organic  2018
#
#               region
# 0             Albany
# 1             Albany
# 2             Albany
# 3             Albany
# 4             Albany
# ..               ...
# 7   WestTexNewMexico
# 8   WestTexNewMexico
# 9   WestTexNewMexico
# 10  WestTexNewMexico
# 11  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
df['region'].nunique()
# Out:
# 54

# %%
# 날짜가 뒤죽박죽이니까, 날짜로 정렬
df.sort_values('Date', inplace= True)

# %%
df.head(3)
# Out:
#           Date  AveragePrice  Total Volume     4046      4225    4770
# 51  2015-01-04          1.75      27365.89  9307.34   3844.81  615.28  \
# 51  2015-01-04          1.49      17723.17  1189.35  15628.27    0.00
# 51  2015-01-04          1.68       2896.72   161.68    206.96    0.00
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags     type  year
# 51    13598.46    13061.10      537.36          0.0  organic  2015  \
# 51      905.55      905.55        0.00          0.0  organic  2015
# 51     2528.08     2528.08        0.00          0.0  organic  2015
#
#                 region
# 51           Southeast
# 51             Chicago
# 51  HarrisburgScranton

# %%
df.tail()
# Out:
#          Date  AveragePrice  Total Volume        4046       4225       4770
# 0  2018-03-25          1.36     908202.13   142681.06  463136.28  174975.75  \
# 0  2018-03-25          0.70    9010588.32  3999735.71  966589.50   30130.82
# 0  2018-03-25          1.42     163496.70    29253.30    5080.04       0.00
# 0  2018-03-25          1.70     190257.38    29644.09   70982.10       0.00
# 0  2018-03-25          1.34    1774776.77    63905.98  908653.71     843.45
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year
# 0   127409.04   103579.41    22467.04      1362.59  conventional  2018  \
# 0  4014132.29  3398569.92   546409.74     69152.63  conventional  2018
# 0   129163.36   109052.26    20111.10         0.00       organic  2018
# 0    89631.19    89424.11      207.08         0.00       organic  2018
# 0   801373.63   774634.09    23833.93      2905.61  conventional  2018
#
#          region
# 0       Chicago
# 0  SouthCentral
# 0  SouthCentral
# 0    California
# 0       NewYork

# %%
# 날짜별로 아보카도 가격이 어떻게 변하는지 ,차트로 표시

# %%
df_date = df.groupby('Date')['AveragePrice'].mean()

# %%
df_date
# Out:
# Date
# 2015-01-04    1.301296
# 2015-01-11    1.370648
# 2015-01-18    1.391111
# 2015-01-25    1.397130
# 2015-02-01    1.247037
#                 ...
# 2018-02-25    1.359630
# 2018-03-04    1.350185
# 2018-03-11    1.335093
# 2018-03-18    1.313704
# 2018-03-25    1.346852
# Name: AveragePrice, Length: 169, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_date)
plt.show()

# %%
df['year'].value_counts()
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
import seaborn as sb

# %%
sb.countplot(data = df , x = 'year')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 날짜컬럼이 년월일만 되어있는데.
# 요일정보를 알고 싶다.
# 요일정보가 있으면, 각 요일별로 가격도 표시할수 있다.

# %%
from datetime import date

# %%
date(2015, 1, 4).weekday()
# Out:
# 6

# %%
df.head()
# Out:
#           Date  AveragePrice  Total Volume     4046      4225     4770
# 51  2015-01-04          1.75      27365.89  9307.34   3844.81   615.28  \
# 51  2015-01-04          1.49      17723.17  1189.35  15628.27     0.00
# 51  2015-01-04          1.68       2896.72   161.68    206.96     0.00
# 51  2015-01-04          1.52      54956.80  3013.04  35456.88  1561.70
# 51  2015-01-04          1.64       1505.12     1.27   1129.50     0.00
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year
# 51    13598.46    13061.10      537.36          0.0       organic  2015  \
# 51      905.55      905.55        0.00          0.0       organic  2015
# 51     2528.08     2528.08        0.00          0.0       organic  2015
# 51    14925.18    11264.80     3660.38          0.0  conventional  2015
# 51      374.35      186.67      187.68          0.0       organic  2015
#
#                 region
# 51           Southeast
# 51             Chicago
# 51  HarrisburgScranton
# 51          Pittsburgh
# 51               Boise

# %%
df['Date'] # 날짜지만 문자열(object) 이다
# Out:
# 51    2015-01-04
# 51    2015-01-04
# 51    2015-01-04
# 51    2015-01-04
# 51    2015-01-04
#          ...
# 0     2018-03-25
# 0     2018-03-25
# 0     2018-03-25
# 0     2018-03-25
# 0     2018-03-25
# Name: Date, Length: 18249, dtype: object

# %%
df['weekday'] = pd.to_datetime(df['Date']).dt.weekday # datetime로 문자열을 날짜형식(datetime64[ns]) 으로 변경

# %%
df
# Out:
#           Date  AveragePrice  Total Volume        4046       4225       4770
# 51  2015-01-04          1.75      27365.89     9307.34    3844.81     615.28  \
# 51  2015-01-04          1.49      17723.17     1189.35   15628.27       0.00
# 51  2015-01-04          1.68       2896.72      161.68     206.96       0.00
# 51  2015-01-04          1.52      54956.80     3013.04   35456.88    1561.70
# 51  2015-01-04          1.64       1505.12        1.27    1129.50       0.00
# ..         ...           ...           ...         ...        ...        ...
# 0   2018-03-25          1.36     908202.13   142681.06  463136.28  174975.75
# 0   2018-03-25          0.70    9010588.32  3999735.71  966589.50   30130.82
# 0   2018-03-25          1.42     163496.70    29253.30    5080.04       0.00
# 0   2018-03-25          1.70     190257.38    29644.09   70982.10       0.00
# 0   2018-03-25          1.34    1774776.77    63905.98  908653.71     843.45
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year
# 51    13598.46    13061.10      537.36         0.00       organic  2015  \
# 51      905.55      905.55        0.00         0.00       organic  2015
# 51     2528.08     2528.08        0.00         0.00       organic  2015
# 51    14925.18    11264.80     3660.38         0.00  conventional  2015
# 51      374.35      186.67      187.68         0.00       organic  2015
# ..         ...         ...         ...          ...           ...   ...
# 0    127409.04   103579.41    22467.04      1362.59  conventional  2018
# 0   4014132.29  3398569.92   546409.74     69152.63  conventional  2018
# 0    129163.36   109052.26    20111.10         0.00       organic  2018
# 0     89631.19    89424.11      207.08         0.00       organic  2018
# 0    801373.63   774634.09    23833.93      2905.61  conventional  2018
#
#                 region  weekdat  weekday
# 51           Southeast        6        6
# 51             Chicago        6        6
# 51  HarrisburgScranton        6        6
# 51          Pittsburgh        6        6
# 51               Boise        6        6
# ..                 ...      ...      ...
# 0              Chicago        6        6
# 0         SouthCentral        6        6
# 0         SouthCentral        6        6
# 0           California        6        6
# 0              NewYork        6        6
#
# [18249 rows x 15 columns]

# %%
del df['weekdat']

# %%
df
# Out:
#           Date  AveragePrice  Total Volume        4046       4225       4770
# 51  2015-01-04          1.75      27365.89     9307.34    3844.81     615.28  \
# 51  2015-01-04          1.49      17723.17     1189.35   15628.27       0.00
# 51  2015-01-04          1.68       2896.72      161.68     206.96       0.00
# 51  2015-01-04          1.52      54956.80     3013.04   35456.88    1561.70
# 51  2015-01-04          1.64       1505.12        1.27    1129.50       0.00
# ..         ...           ...           ...         ...        ...        ...
# 0   2018-03-25          1.36     908202.13   142681.06  463136.28  174975.75
# 0   2018-03-25          0.70    9010588.32  3999735.71  966589.50   30130.82
# 0   2018-03-25          1.42     163496.70    29253.30    5080.04       0.00
# 0   2018-03-25          1.70     190257.38    29644.09   70982.10       0.00
# 0   2018-03-25          1.34    1774776.77    63905.98  908653.71     843.45
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year
# 51    13598.46    13061.10      537.36         0.00       organic  2015  \
# 51      905.55      905.55        0.00         0.00       organic  2015
# 51     2528.08     2528.08        0.00         0.00       organic  2015
# 51    14925.18    11264.80     3660.38         0.00  conventional  2015
# 51      374.35      186.67      187.68         0.00       organic  2015
# ..         ...         ...         ...          ...           ...   ...
# 0    127409.04   103579.41    22467.04      1362.59  conventional  2018
# 0   4014132.29  3398569.92   546409.74     69152.63  conventional  2018
# 0    129163.36   109052.26    20111.10         0.00       organic  2018
# 0     89631.19    89424.11      207.08         0.00       organic  2018
# 0    801373.63   774634.09    23833.93      2905.61  conventional  2018
#
#                 region  weekday
# 51           Southeast        6
# 51             Chicago        6
# 51  HarrisburgScranton        6
# 51          Pittsburgh        6
# 51               Boise        6
# ..                 ...      ...
# 0              Chicago        6
# 0         SouthCentral        6
# 0         SouthCentral        6
# 0           California        6
# 0              NewYork        6
#
# [18249 rows x 14 columns]

# %%
# 가격 에측

# %%
# 타임시리즈 데이터를 예측하는 라이브러리 중에
# 페이스북이 개발한 Prophet 라이브러리를 사용

# %%
# 프로펫(Prophet)은 2개 컬럼만 있으면, 예측 가능하다.
# 날짜 컬럼과, 예측하려는 컬럼~~!

# %%
df.head(3)
# Out:
#           Date  AveragePrice  Total Volume     4046      4225    4770
# 51  2015-01-04          1.75      27365.89  9307.34   3844.81  615.28  \
# 51  2015-01-04          1.49      17723.17  1189.35  15628.27    0.00
# 51  2015-01-04          1.68       2896.72   161.68    206.96    0.00
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags     type  year
# 51    13598.46    13061.10      537.36          0.0  organic  2015  \
# 51      905.55      905.55        0.00          0.0  organic  2015
# 51     2528.08     2528.08        0.00          0.0  organic  2015
#
#                 region  weekday
# 51           Southeast        6
# 51             Chicago        6
# 51  HarrisburgScranton        6

# %%
df_avocado = df[ ['Date', 'AveragePrice'] ]

# %%
df_avocado
# Out:
#           Date  AveragePrice
# 51  2015-01-04          1.75
# 51  2015-01-04          1.49
# 51  2015-01-04          1.68
# 51  2015-01-04          1.52
# 51  2015-01-04          1.64
# ..         ...           ...
# 0   2018-03-25          1.36
# 0   2018-03-25          0.70
# 0   2018-03-25          1.42
# 0   2018-03-25          1.70
# 0   2018-03-25          1.34
#
# [18249 rows x 2 columns]

# %%
# 1. 컬럼명을, 프로펫 라이브러리가 인식할 수 있도록 바꿔준다.

# %%
df_prophet = df_avocado.rename( columns={'Date':'ds' , 'AveragePrice':'y'} )

# %%
df_prophet
# Out:
#             ds     y
# 51  2015-01-04  1.75
# 51  2015-01-04  1.49
# 51  2015-01-04  1.68
# 51  2015-01-04  1.52
# 51  2015-01-04  1.64
# ..         ...   ...
# 0   2018-03-25  1.36
# 0   2018-03-25  0.70
# 0   2018-03-25  1.42
# 0   2018-03-25  1.70
# 0   2018-03-25  1.34
#
# [18249 rows x 2 columns]

# %%
# 2. 데이터를 학습시킨다.

# %%
from prophet import Prophet

m = Prophet()

# %%
m.fit(df_prophet)
# Out:
# 11:07:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:07 - cmdstanpy - INFO - Chain [1] done processing

# %%
# 3. 예측에 사용할 데이터 프레임 만든다.

# %%
future = m.make_future_dataframe(periods= 365, freq= 'D' )

# %%
# 4. 예측한다.

# %%
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper
# 0   2015-01-04  1.497220    0.916143    1.887407     1.497220     1.497220  \
# 1   2015-01-11  1.492220    0.914371    1.884612     1.492220     1.492220
# 2   2015-01-18  1.487221    0.885326    1.881094     1.487221     1.487221
# 3   2015-01-25  1.482221    0.861641    1.878697     1.482221     1.482221
# 4   2015-02-01  1.477222    0.796430    1.801623     1.477222     1.477222
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.159300    0.477981    1.567404     0.963771     1.327591
# 530 2019-03-22  1.158564    0.521806    1.632641     0.962386     1.327949
# 531 2019-03-23  1.157828    0.550020    1.657503     0.961000     1.328306
# 532 2019-03-24  1.157092    0.544460    1.569956     0.959615     1.328664
# 533 2019-03-25  1.156356    0.577296    1.617367     0.958230     1.329011
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly
# 0         -0.112756             -0.112756             -0.112756 -0.112756  \
# 1         -0.104283             -0.104283             -0.104283 -0.104283
# 2         -0.103967             -0.103967             -0.103967 -0.103967
# 3         -0.122958             -0.122958             -0.122958 -0.122958
# 4         -0.151372             -0.151372             -0.151372 -0.151372
# ..              ...                   ...                   ...       ...
# 529       -0.086201             -0.086201             -0.086201 -0.086201
# 530       -0.084544             -0.084544             -0.084544 -0.084544
# 531       -0.082616             -0.082616             -0.082616 -0.082616
# 532       -0.080435             -0.080435             -0.080435 -0.080435
# 533       -0.078029             -0.078029             -0.078029 -0.078029
#
#      yearly_lower  yearly_upper  multiplicative_terms
# 0       -0.112756     -0.112756                   0.0  \
# 1       -0.104283     -0.104283                   0.0
# 2       -0.103967     -0.103967                   0.0
# 3       -0.122958     -0.122958                   0.0
# 4       -0.151372     -0.151372                   0.0
# ..            ...           ...                   ...
# 529     -0.086201     -0.086201                   0.0
# 530     -0.084544     -0.084544                   0.0
# 531     -0.082616     -0.082616                   0.0
# 532     -0.080435     -0.080435                   0.0
# 533     -0.078029     -0.078029                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                           0.0                         0.0  1.384464
# 1                           0.0                         0.0  1.387937
# 2                           0.0                         0.0  1.383254
# 3                           0.0                         0.0  1.359263
# 4                           0.0                         0.0  1.325850
# ..                          ...                         ...       ...
# 529                         0.0                         0.0  1.073099
# 530                         0.0                         0.0  1.074019
# 531                         0.0                         0.0  1.075212
# 532                         0.0                         0.0  1.076657
# 533                         0.0                         0.0  1.078326
#
# [534 rows x 16 columns]

# %%
# 5. 예측 결과를 차트로 나타낸다.

# %%
m.plot(forecast, xlabel='Date', ylabel='Price')
plt.savefig('fig1.jpg')

# %%
m.plot_components(forecast)
plt.savefig('fig2.jpg')

# %%
# 지금까지의 예측은, 미국 지역 전체에 대한 데이터 예측이었다.
# West 지역은 어떨지 예측해 보시오.

# %%
df['region'] == 'West'
# Out:
# 51    False
# 51    False
# 51    False
# 51    False
# 51    False
#       ...
# 0     False
# 0     False
# 0     False
# 0     False
# 0     False
# Name: region, Length: 18249, dtype: bool

# %%
df_west = df.loc[  df['region'] == 'West'  ,  ]

# %%
df_prophet = df_west[ ['Date','AveragePrice'] ]

# %%
df_prophet.rename( columns={'Date':'ds' , 'AveragePrice':'y'} , inplace=True)
# Out:
# C:\Users\jaehong\AppData\Local\Temp\ipykernel_9188\1115952650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prophet.rename( columns={'Date':'ds' , 'AveragePrice':'y'} , inplace=True)

# %%
df_prophet
# Out:
#             ds     y
# 51  2015-01-04  1.40
# 51  2015-01-04  0.89
# 50  2015-01-11  1.39
# 50  2015-01-11  0.95
# 49  2015-01-18  0.96
# ..         ...   ...
# 2   2018-03-11  1.00
# 1   2018-03-18  1.73
# 1   2018-03-18  0.99
# 0   2018-03-25  0.93
# 0   2018-03-25  1.60
#
# [338 rows x 2 columns]

# %%
m2 = Prophet()

# %%
m2.fit(df_prophet)
# Out:
# 11:44:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:44:24 - cmdstanpy - INFO - Chain [1] done processing

# %%
future2 = m2.make_future_dataframe(periods= 365, freq='D')

# %%
forecast2 = m2.predict(future2)

# %%
m2.plot(forecast2)
plt.savefig('fig3.jpg')

# %%
m2.plot_components(forecast2)
plt.savefig('fig4.jpg')
